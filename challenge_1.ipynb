# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
df=pd.read_csv('retail_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302010 entries, 0 to 302009
# Data columns (total 30 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Transaction_ID    301677 non-null  float64
#  1   Customer_ID       301702 non-null  float64
#  2   Name              301628 non-null  object
#  3   Email             301663 non-null  object
#  4   Phone             301648 non-null  float64
#  5   Address           301695 non-null  object
#  6   City              301762 non-null  object
#  7   State             301729 non-null  object
#  8   Zipcode           301670 non-null  float64
#  9   Country           301739 non-null  object
#  10  Age               301837 non-null  float64
#  11  Gender            301693 non-null  object
#  12  Income            301720 non-null  object
#  13  Customer_Segment  301795 non-null  object
#  14  Date              301651 non-null  object
#  15  Year              301660 non-null  float64
#  16  Month             301737 non-null  object
#  17  Time              301660 non-null  object
#  18  Total_Purchases   301649 non-null  float64
#  19  Amount            301653 non-null  float64
#  20  Total_Amount      301660 non-null  float64
#  21  Product_Category  301727 non-null  object
#  22  Product_Brand     301729 non-null  object
#  23  Product_Type      302010 non-null  object
#  24  Feedback          301826 non-null  object
#  25  Shipping_Method   301673 non-null  object
#  26  Payment_Method    301713 non-null  object
#  27  Order_Status      301775 non-null  object
#  28  Ratings           301826 non-null  float64
#  29  products          302010 non-null  object
# dtypes: float64(10), object(20)
# memory usage: 69.1+ MB

# %%
df.shape
# Out:
# (302010, 30)

# %%
df.describe()
# Out:
#        Transaction_ID    Customer_ID         Phone        Zipcode  \
# count    3.016770e+05  301702.000000  3.016480e+05  301670.000000
# mean     5.495823e+06   55006.553934  5.501464e+09   50298.951019
# std      2.595565e+06   26005.675200  2.596017e+09   28972.807134
# min      1.000007e+06   10000.000000  1.000049e+09     501.000000
# 25%      3.247930e+06   32469.250000  3.255061e+09   25425.000000
# 50%      5.499657e+06   55012.000000  5.505812e+09   50602.500000
# 75%      7.739509e+06   77511.000000  7.749860e+09   75252.000000
# max      9.999995e+06   99999.000000  9.999996e+09   99949.000000
#
#                  Age           Year  Total_Purchases         Amount  \
# count  301837.000000  301660.000000    301649.000000  301653.000000
# mean       35.481326    2023.165113         5.359729     255.163659
# std        15.021933       0.371283         2.868575     141.389640
# min        18.000000    2023.000000         1.000000      10.000219
# 25%        22.000000    2023.000000         3.000000     132.890764
# 50%        32.000000    2023.000000         5.000000     255.470969
# 75%        46.000000    2023.000000         8.000000     377.672606
# max        70.000000    2024.000000        10.000000     499.997911
#
#         Total_Amount        Ratings
# count  301660.000000  301826.000000
# mean     1367.651156       3.162670
# std      1128.998515       1.320827
# min        10.003750       1.000000
# 25%       438.724278       2.000000
# 50%      1041.117547       3.000000
# 75%      2029.999853       4.000000
# max      4999.625796       5.000000

# %%
df.shape
# Out:
# (302010, 30)

# %%
age=df['Age']
print(age)
# Out:
# 0         21.0
# 1         19.0
# 2         48.0
# 3         56.0
# 4         22.0
#           ...
# 302005    31.0
# 302006    35.0
# 302007    41.0
# 302008    41.0
# 302009    28.0
# Name: Age, Length: 302010, dtype: float64

# %%
df.head(5)
# Out:
#    Transaction_ID  Customer_ID                 Name                Email  \
# 0       8691788.0      37249.0  Michelle Harrington    Ebony39@gmail.com
# 1       2174773.0      69749.0          Kelsey Hill     Mark36@gmail.com
# 2       6679610.0      30192.0         Scott Jensen    Shane85@gmail.com
# 3       7232460.0      62101.0        Joseph Miller     Mary34@gmail.com
# 4       4983775.0      27901.0        Debra Coleman  Charles30@gmail.com
#
#           Phone                      Address        City            State  \
# 0  1.414787e+09            3959 Amanda Burgs    Dortmund           Berlin
# 1  6.852900e+09           82072 Dawn Centers  Nottingham          England
# 2  8.362160e+09            4133 Young Canyon     Geelong  New South Wales
# 3  2.776752e+09  8148 Thomas Creek Suite 100    Edmonton          Ontario
# 4  9.098268e+09    5813 Lori Ports Suite 269     Bristol          England
#
#    Zipcode    Country  ...  Total_Amount Product_Category  Product_Brand  \
# 0  77985.0    Germany  ...    324.086270         Clothing           Nike
# 1  99071.0         UK  ...    806.707815      Electronics        Samsung
# 2  75929.0  Australia  ...   1063.432799            Books  Penguin Books
# 3  88420.0     Canada  ...   2466.854021       Home Decor     Home Depot
# 4  48704.0         UK  ...    248.553049          Grocery         Nestle
#
#   Product_Type   Feedback  Shipping_Method Payment_Method Order_Status  \
# 0       Shorts  Excellent         Same-Day     Debit Card      Shipped
# 1       Tablet  Excellent         Standard    Credit Card   Processing
# 2   Children's    Average         Same-Day    Credit Card   Processing
# 3        Tools  Excellent         Standard         PayPal   Processing
# 4    Chocolate        Bad         Standard           Cash      Shipped
#
#    Ratings           products
# 0      5.0     Cycling shorts
# 1      4.0         Lenovo Tab
# 2      2.0   Sports equipment
# 3      4.0      Utility knife
# 4      1.0  Chocolate cookies
#
# [5 rows x 30 columns]

# %% [markdown]
# All Age Related Numerical Analysis

# %%
age.value_counts().max()
# Out:
# 34678

# %%
age.min()
# Out:
# 18.0

# %%
age.max()
# Out:
# 70.0

# %%
age.mean()
# Out:
# np.float64(35.481326013709385)

# %%
age.median()
# Out:
# 32.0

# %%
age.std()
# Out:
# 15.021932528508106

# %%
age.var()
# Out:
# 225.65845689104995

# %%
age.skew()
# Out:
# np.float64(0.6525034070780483)

# %% [markdown]
# Age variable
# numemrical representation

# %%
plt.figure(figsize = (16,7))
sns.barplot(df['Age'].value_counts() , palette = 'coolwarm' , edgecolor = 'black')

plt.title('ordered of all aged person')
plt.xlabel('Age')
plt.ylabel('Count')
plt.xticks(rotation = 90)
plt.grid(False)
plt.show()

# %%
def plot_categorical_donut(dataframe, column_name, n_categories=7, figsize=(10, 10)):
    """
    Generates and displays a donut chart for the top N categories of a specified column.

    Parameters:
    dataframe (pd.DataFrame): The input DataFrame.
    column_name (str): The name of the categorical column to plot.
    n_categories (int): The number of top categories to display explicitly.
                        Remaining categories will be grouped into 'Other'.
    figsize (tuple): A tuple (width, height) for the figure size.
    """
    if column_name not in dataframe.columns:
        print(f"Error: Column '{column_name}' not found in the DataFrame.")
        return

    # Calculate value counts
    counts = dataframe[column_name].value_counts()

    # Prepare data for plotting: select top N and sum the rest into 'Other'
    if len(counts) > n_categories:
        top_n = counts.head(n_categories)
        other_sum = counts.iloc[n_categories:].sum()
        if other_sum > 0:
            plot_data = pd.concat([top_n, pd.Series({'Other': other_sum})])
        else:
            plot_data = top_n
    else:
        plot_data = counts

    # Define colors
    colors = sns.color_palette('pastel', n_colors=len(plot_data))
    if 'Other' in plot_data.index:
        colors = sns.color_palette('pastel', n_colors=len(plot_data) - 1) + ['gray'] # Distinct color for 'Other'

    # Create figure and axis for the plot
    fig, ax = plt.subplots(figsize=figsize)

    # Plotting the donut chart
    wedges, texts, autotexts = ax.pie(
        plot_data,
        labels=plot_data.index,
        autopct='%1.1f%%',       # Format percentages
        startangle=90,           # Start at the top
        colors=colors,
        pctdistance=0.8,         # Position of percentage labels (closer to center of donut hole)
        labeldistance=1.05,      # Position of category labels (outside the donut)
        wedgeprops=dict(width=0.4, edgecolor='black', linewidth=1) # Donut hole via width
    )

    # Customize percentage labels
    for autotext in autotexts:
        autotext.set_color('black')
        autotext.set_fontsize(12)
        autotext.set_fontweight('bold')

    # Customize category labels
    for text in texts:
        text.set_fontsize(12)

    # Set title
    ax.set_title(f'Top 5 Age who ordered most', fontsize=16, fontweight='bold')
    ax.axis('equal') # Ensure circle

    plt.tight_layout()
    plt.show()

# %%
plot_categorical_donut(df, 'Age', n_categories=5 , figsize=(10,8))

# %%
a=df[df['Customer_ID']==37249.0]
print(a)
# Out:
#         Transaction_ID  Customer_ID                 Name  \
# 0            8691788.0      37249.0  Michelle Harrington
# 9670         2322638.0      37249.0    Mr. Charles Scott
# 61773        1814136.0      37249.0          David Kelly
# 100184       4895457.0      37249.0        Sheryl Wright
# 205362       5836653.0      37249.0          Sierra Mann
#
#                         Email         Phone               Address        City  \
# 0           Ebony39@gmail.com  1.414787e+09     3959 Amanda Burgs    Dortmund
# 9670       Joseph46@gmail.com  3.464625e+09    3393 Victor Street  Portsmouth
# 61773     Kathryn94@gmail.com  3.407689e+09     54848 Daniel Pass   Saskatoon
# 100184  Christine32@gmail.com  6.094710e+09    4652 Bradley Fords    Hamilton
# 205362    Melinda29@gmail.com  6.823401e+09  37838 Bailey Centers  Gold Coast
#
#                   State  Zipcode    Country  ...  Total_Amount  \
# 0                Berlin  77985.0    Germany  ...    324.086270
# 9670            England  99762.0         UK  ...    531.117667
# 61773           Ontario  65852.0     Canada  ...   2276.302319
# 100184          Ontario  84617.0     Canada  ...    594.550754
# 205362  New South Wales  55493.0  Australia  ...   2759.332518
#
#        Product_Category Product_Brand Product_Type   Feedback  \
# 0              Clothing          Nike       Shorts  Excellent
# 9670        Electronics          Sony   Smartphone       Good
# 61773        Home Decor    Home Depot    Furniture    Average
# 100184         Clothing          Zara        Shirt  Excellent
# 205362          Grocery         Pepsi        Water    Average
#
#         Shipping_Method Payment_Method Order_Status  Ratings        products
# 0              Same-Day     Debit Card      Shipped      5.0  Cycling shorts
# 9670            Express         PayPal    Delivered      3.0     Sony Xperia
# 61773           Express         PayPal    Delivered      2.0             Bed
# 100184          Express           Cash      Shipped      5.0      Polo shirt
# 205362         Same-Day         PayPal      Shipped      2.0  Flavored water
#
# [5 rows x 30 columns]

# %%
b=df[df['Name']=='Sierra Mann']
print(b['Age'])
# Out:
# 205362    29.0
# Name: Age, dtype: float64

# %% [markdown]
# Categorical Representation

# %%
def plot_categorical_donut(dataframe, column_name, n_categories=7, figsize=(10, 10)):
    """
    Generates and displays a donut chart for the top N categories of a specified column.

    Parameters:
    dataframe (pd.DataFrame): The input DataFrame.
    column_name (str): The name of the categorical column to plot.
    n_categories (int): The number of top categories to display explicitly.
                        Remaining categories will be grouped into 'Other'.
    figsize (tuple): A tuple (width, height) for the figure size.
    """
    if column_name not in dataframe.columns:
        print(f"Error: Column '{column_name}' not found in the DataFrame.")
        return

    # Calculate value counts
    counts = dataframe[column_name].value_counts()

    # Prepare data for plotting: select top N and sum the rest into 'Other'
    if len(counts) > n_categories:
        top_n = counts.head(n_categories)
        other_sum = counts.iloc[n_categories:].sum()
        if other_sum > 0:
            plot_data = pd.concat([top_n, pd.Series({'Other': other_sum})])
        else:
            plot_data = top_n
    else:
        plot_data = counts

    # Define colors
    colors = sns.color_palette('pastel', n_colors=len(plot_data))
    if 'Other' in plot_data.index:
        colors = sns.color_palette('pastel', n_colors=len(plot_data) - 1) + ['gray'] # Distinct color for 'Other'

    # Create figure and axis for the plot
    fig, ax = plt.subplots(figsize=figsize)

    # Plotting the donut chart
    wedges, texts, autotexts = ax.pie(
        plot_data,
        labels=plot_data.index,
        autopct='%1.1f%%',       # Format percentages
        startangle=90,           # Start at the top
        colors=colors,
        pctdistance=0.8,         # Position of percentage labels (closer to center of donut hole)
        labeldistance=1.05,      # Position of category labels (outside the donut)
        wedgeprops=dict(width=0.4, edgecolor='black', linewidth=1) # Donut hole via width
    )

    # Customize percentage labels
    for autotext in autotexts:
        autotext.set_color('black')
        autotext.set_fontsize(12)
        autotext.set_fontweight('bold')

    # Customize category labels
    for text in texts:
        text.set_fontsize(12)

    # Set title
    ax.set_title(f'Product Categories', fontsize=16, fontweight='bold')
    ax.axis('equal') # Ensure circle

    plt.tight_layout()
    plt.show()

# %%
plot_categorical_donut(df, 'Product_Category', n_categories=5 , figsize=(10,8))

# %%
df['products'].nunique()
# Out:
# 318

# %%
def plot_categorical_donut(dataframe, column_name, n_categories=7, figsize=(10, 10)):
    """
    Generates and displays a donut chart for the top N categories of a specified column.

    Parameters:
    dataframe (pd.DataFrame): The input DataFrame.
    column_name (str): The name of the categorical column to plot.
    n_categories (int): The number of top categories to display explicitly.
                        Remaining categories will be grouped into 'Other'.
    figsize (tuple): A tuple (width, height) for the figure size.
    """
    if column_name not in dataframe.columns:
        print(f"Error: Column '{column_name}' not found in the DataFrame.")
        return

    # Calculate value counts
    counts = dataframe[column_name].value_counts().nlargest(5)

    # Prepare data for plotting: select top N and sum the rest into 'Other'
    if len(counts) > n_categories:
        top_n = counts.head(n_categories)
        other_sum = counts.iloc[n_categories:].sum()
        if other_sum > 0:
            plot_data = pd.concat([top_n, pd.Series({'Other': other_sum})])
        else:
            plot_data = top_n
    else:
        plot_data = counts

    # Define colors
    colors = sns.color_palette('pastel', n_colors=len(plot_data))
    if 'Other' in plot_data.index:
        colors = sns.color_palette('pastel', n_colors=len(plot_data) - 1) + ['gray'] # Distinct color for 'Other'

    # Create figure and axis for the plot
    fig, ax = plt.subplots(figsize=figsize)

    # Plotting the donut chart
    wedges, texts, autotexts = ax.pie(
        plot_data,
        labels=plot_data.index,
        autopct='%1.1f%%',       # Format percentages
        startangle=90,           # Start at the top
        colors=colors,
        pctdistance=0.8,         # Position of percentage labels (closer to center of donut hole)
        labeldistance=1.05,      # Position of category labels (outside the donut)
        wedgeprops=dict(width=0.4, edgecolor='black', linewidth=1) # Donut hole via width
    )

    # Customize percentage labels
    for autotext in autotexts:
        autotext.set_color('black')
        autotext.set_fontsize(12)
        autotext.set_fontweight('bold')

    # Customize category labels
    for text in texts:
        text.set_fontsize(12)

    # Set title
    ax.set_title(f'Top 5 products', fontsize=16, fontweight='bold')
    ax.axis('equal') # Ensure circle

    plt.tight_layout()
    plt.show()

# %%
plot_categorical_donut(df, 'products', n_categories=5 , figsize=(10,8))

# %%
df['products'].value_counts()
# Out:
# products
# Spring water       2508
# Bottled water      2496
# Mystery            2496
# Artesian water     2478
# Distilled water    2475
#                    ...
# Screwdriver set     559
# Towel rack          558
# Razer Blade         556
# Parka               549
# Package AC          223
# Name: count, Length: 318, dtype: int64

# %%
# --- Calculate the proportion of each Product_Category within top N Store_Name ---

# 1. Create a cross-tabulation (contingency table) of counts
cross_tab = pd.crosstab(df['Age'], df['products'])

# 2. Keep only the top 5 product categories (by total count across stores)
top_products = cross_tab.sum().nlargest(5).index
cross_tab = cross_tab[top_products]

# Sort Age in ascending order
cross_tab = cross_tab.sort_index()

# 2. Convert counts to proportions (percentages) along the rows (axis=1)
# This calculates, for each store, what percentage each product category makes up of its total.
percentage_cross_tab = cross_tab.apply(lambda r: r / r.sum(), axis=1)


percentage_cross_tab.index = percentage_cross_tab.index.astype(int)
percentage_cross_tab = percentage_cross_tab.sort_index()
# Sort stores by total count or alphabetically for consistent visualization (optional)
# For example, sorting by total sales volume (sum of units per store) might be more insightful if units column was used
# For now, let's sort by the sum of percentages for clarity or alphabetical
# percentage_cross_tab = percentage_cross_tab.sort_values(by=percentage_cross_tab.columns[0], ascending=False) # Or by any other column if meaningful

# --- Plotting the Stacked Bar Chart ---
plt.figure(figsize=(20, 10)) # Adjust figure size as needed

# Use the .plot() method directly on the DataFrame for convenience with stacked bars
ax = percentage_cross_tab.plot(
    kind='bar',
    stacked=True,
    colormap='viridis', # Choose a suitable colormap
    ax=plt.gca(),       # Get current axes
    edgecolor='black'
)

plt.title('Top 5 Product Distribution in every age', fontsize=20, fontweight='bold')
plt.xlabel('Age', fontsize=16)
plt.ylabel('Product Indicate', fontsize=16)
plt.xticks(rotation=45, ha='right', fontsize=12) # Rotate store names for readability
plt.yticks(fontsize=12)
plt.legend(title='Product Category', bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=10) # Place legend outside
plt.grid(False) # Only y-grid makes sense for stacked bars

plt.tight_layout() # Adjust layout to prevent labels/titles from being cut off
plt.show()

# %%
# Count how many times each rating appears for each age
age_rating = pd.crosstab(df['Age'], df['Ratings'])

plt.figure(figsize=(12,6))
age_rating.plot(kind='bar', figsize=(24,6), edgecolor='black')

plt.title('Ratings Distribution by Age')
plt.xlabel('Age')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Ratings')
plt.show()

# %%
a=df[df['Age']==46]
a['Ratings'].value_counts()
# Out:
# Ratings
# 4.0    12936
# 5.0    12052
# 2.0     4601
# 3.0      822
# 1.0      347
# Name: count, dtype: int64

# %%
def plot_categorical_donut(dataframe, column_name, n_categories=7, figsize=(10, 10)):
    """
    Generates and displays a donut chart for the top N categories of a specified column.

    Parameters:
    dataframe (pd.DataFrame): The input DataFrame.
    column_name (str): The name of the categorical column to plot.
    n_categories (int): The number of top categories to display explicitly.
                        Remaining categories will be grouped into 'Other'.
    figsize (tuple): A tuple (width, height) for the figure size.
    """
    if column_name not in dataframe.columns:
        print(f"Error: Column '{column_name}' not found in the DataFrame.")
        return

    # Calculate value counts
    counts = dataframe[column_name].value_counts()

    # Prepare data for plotting: select top N and sum the rest into 'Other'
    if len(counts) > n_categories:
        top_n = counts.head(n_categories)
        other_sum = counts.iloc[n_categories:].sum()
        if other_sum > 0:
            plot_data = pd.concat([top_n, pd.Series({'Other': other_sum})])
        else:
            plot_data = top_n
    else:
        plot_data = counts

    # Define colors
    colors = sns.color_palette('pastel', n_colors=len(plot_data))
    if 'Other' in plot_data.index:
        colors = sns.color_palette('pastel', n_colors=len(plot_data) - 1) + ['gray'] # Distinct color for 'Other'

    # Create figure and axis for the plot
    fig, ax = plt.subplots(figsize=figsize)

    # Plotting the donut chart
    wedges, texts, autotexts = ax.pie(
        plot_data,
        labels=plot_data.index,
        autopct='%1.1f%%',       # Format percentages
        startangle=90,           # Start at the top
        colors=colors,
        pctdistance=0.8,         # Position of percentage labels (closer to center of donut hole)
        labeldistance=1.05,      # Position of category labels (outside the donut)
        wedgeprops=dict(width=0.4, edgecolor='black', linewidth=1) # Donut hole via width
    )

    # Customize percentage labels
    for autotext in autotexts:
        autotext.set_color('black')
        autotext.set_fontsize(12)
        autotext.set_fontweight('bold')

    # Customize category labels
    for text in texts:
        text.set_fontsize(12)

    # Set title
    ax.set_title(f'', fontsize=16, fontweight='bold')
    ax.axis('equal') # Ensure circle

    plt.tight_layout()
    plt.show()

# %%
plot_categorical_donut(df, 'Country', n_categories=7 , figsize=(10,8))

# %%
usa=df[df['Country']=='USA']
plot_categorical_donut(usa, 'City' , figsize=(10,8))
usa['City'].nunique()
# Out:
# 51

# %%
usa['City'].nunique()
# Out:
# 51

# %%
usa=df[df['Country']=='UK']
plot_categorical_donut(usa, 'City' , figsize=(10,8))
usa['City'].nunique()
# Out:
# 20

# %%
usa=df[df['Country']=='Germany']
plot_categorical_donut(usa, 'City' , figsize=(10,8))
usa['City'].nunique()
# Out:
# 20

# %%
usa=df[df['Country']=='Australia']
plot_categorical_donut(usa, 'City' , figsize=(10,8))
usa['City'].nunique()
# Out:
# 20

# %%
usa=df[df['Country']=='Canada']
plot_categorical_donut(usa, 'City' , figsize=(10,8))
usa['City'].nunique()
# Out:
# 20

# %% [markdown]
# All Temporal Analysis

# %%
df['Date']=pd.DatetimeIndex(df['Date'])

# %%
# --- Prepare data for Monthly Units Sold ---
# Set 'Date' as index, resample by 'M' (month end) and sum 'Units'.
# .reset_index() converts the aggregated Series back into a DataFrame
# with 'Date' as a regular column.
monthly_units_summary = df.set_index('Date')['Total_Purchases'].resample('W').sum().reset_index()


# --- Plotting Monthly Units Sold ---
plt.figure(figsize=(10, 6))

sns.lineplot(
    x='Date',
    y='Total_Purchases',
    data=monthly_units_summary, # Use the monthly aggregated data
    color='magenta',
    linewidth=1.5
)

plt.title('Weekly Units Sold', fontsize=20, fontweight='bold')
plt.xlabel('Date (End of Week)', fontsize=14) # Changed label to reflect monthly aggregation
plt.ylabel('Total Units Sold', fontsize=14) # Changed label to reflect total units
plt.xticks(rotation=90, ha='right')
plt.grid(False) # Added grid for time series readability
plt.show()

# %%
# --- Prepare data for Monthly Units Sold ---
# Set 'Date' as index, resample by 'M' (month end) and sum 'Units'.
# .reset_index() converts the aggregated Series back into a DataFrame
# with 'Date' as a regular column.
monthly_units_summary = df.set_index('Date')['Total_Amount'].resample('W').sum().reset_index()


# --- Plotting Monthly Units Sold ---
plt.figure(figsize=(10, 6))

sns.lineplot(
    x='Date',
    y='Total_Amount',
    data=monthly_units_summary, # Use the monthly aggregated data
    color='magenta',
    linewidth=1.5
)

plt.title('Weekly Amound', fontsize=20, fontweight='bold')
plt.xlabel('Date (End of Week)', fontsize=14) # Changed label to reflect monthly aggregation
plt.ylabel('Total_Amount', fontsize=14) # Changed label to reflect total units
plt.xticks(rotation=90, ha='right')
plt.grid(False) # Added grid for time series readability
plt.show()

# %% [markdown]
# **It not Possible to calculate Profit Because there is no KPI like product making price**

# %%
fig, ax1 = plt.subplots(figsize=(16,8))
weekly = df.set_index('Date').resample('W')[['Total_Purchases', 'Total_Amount']].sum()
# First axis (Units Sold)
ax1.plot(weekly.index, weekly['Total_Purchases'], marker='o', color='Black', label='Units Sold')
ax1.set_xlabel("Week End Date")
ax1.set_ylabel("Units Sold", color='magenta')
ax1.tick_params(axis='y', labelcolor='magenta')

# Second axis (Revenue)
ax2 = ax1.twinx()
ax2.plot(weekly.index, weekly['Total_Amount'], marker='^', color='orange', label='Revenue')
ax2.set_ylabel("Revenue", color='orange')
ax2.tick_params(axis='y', labelcolor='orange')

plt.title("Weekly Sales Performance")
fig.tight_layout()
plt.show()

# %%
# --- Prepare data for Monthly Units Sold ---
# Set 'Date' as index, resample by 'M' (month end) and sum 'Units'.
# .reset_index() converts the aggregated Series back into a DataFrame
# with 'Date' as a regular column.
monthly_units_summary = df.set_index('Date')['Total_Purchases'].resample('M').sum().reset_index()


# --- Plotting Monthly Units Sold ---
plt.figure(figsize=(12, 6))

sns.lineplot(
    x='Date',
    y='Total_Purchases',
    data=monthly_units_summary, # Use the monthly aggregated data
    color='magenta',
    linewidth=1.5
)

plt.title('Monthly Units Sold', fontsize=20, fontweight='bold')
plt.xlabel('Date (End of Month)', fontsize=14) # Changed label to reflect monthly aggregation
plt.ylabel('Total Units Sold', fontsize=14) # Changed label to reflect total units
plt.xticks(rotation=90, ha='right')
plt.grid(False) # Added grid for time series readability
plt.show()

# %%
# --- Prepare data for Monthly Units Sold ---
# Set 'Date' as index, resample by 'M' (month end) and sum 'Units'.
# .reset_index() converts the aggregated Series back into a DataFrame
# with 'Date' as a regular column.
monthly_units_summary = df.set_index('Date')['Total_Amount'].resample('M').sum().reset_index()


# --- Plotting Monthly Units Sold ---
plt.figure(figsize=(12, 6))

sns.lineplot(
    x='Date',
    y='Total_Amount',
    data=monthly_units_summary, # Use the monthly aggregated data
    color='magenta',
    linewidth=1.5
)

plt.title('Monthly Amound', fontsize=20, fontweight='bold')
plt.xlabel('Date (End of Month)', fontsize=14) # Changed label to reflect monthly aggregation
plt.ylabel('Total_Amount', fontsize=14) # Changed label to reflect total units
plt.xticks(rotation=90, ha='right')
plt.grid(False) # Added grid for time series readability
plt.show()

# %% [markdown]
# Similerly i think profit does not possible to **calculate**

# %%
fig, ax1 = plt.subplots(figsize=(16,8))
weekly = df.set_index('Date').resample('M')[['Total_Purchases', 'Total_Amount']].sum()
# First axis (Units Sold)
ax1.plot(weekly.index, weekly['Total_Purchases'], marker='o', color='Black', label='Units Sold')
ax1.set_xlabel("Month End Date")
ax1.set_ylabel("Units Sold", color='magenta')
ax1.tick_params(axis='y', labelcolor='magenta')

# Second axis (Revenue)
ax2 = ax1.twinx()
ax2.plot(weekly.index, weekly['Total_Amount'], marker='^', color='orange', label='Revenue')
ax2.set_ylabel("Revenue", color='orange')
ax2.tick_params(axis='y', labelcolor='orange')

plt.title("Monthly Sales Performance")
fig.tight_layout()
plt.show()

# %%
# --- Prepare data for Monthly Units Sold ---
# Set 'Date' as index, resample by 'M' (month end) and sum 'Units'.
# .reset_index() converts the aggregated Series back into a DataFrame
# with 'Date' as a regular column.
monthly_units_summary = df.set_index('Date')['Total_Purchases'].resample('Q').sum().reset_index()


# --- Plotting Monthly Units Sold ---
plt.figure(figsize=(12, 6))

sns.lineplot(
    x='Date',
    y='Total_Purchases',
    data=monthly_units_summary, # Use the monthly aggregated data
    color='magenta',
    linewidth=1.5
)

plt.title('Quarterly Units Sold', fontsize=20, fontweight='bold')
plt.xlabel('Date (End of Quater)', fontsize=14) # Changed label to reflect monthly aggregation
plt.ylabel('Total Units Sold', fontsize=14) # Changed label to reflect total units
plt.xticks(rotation=90, ha='right')
plt.grid(False) # Added grid for time series readability
plt.show()

# %%
# --- Prepare data for Monthly Units Sold ---
# Set 'Date' as index, resample by 'M' (month end) and sum 'Units'.
# .reset_index() converts the aggregated Series back into a DataFrame
# with 'Date' as a regular column.
monthly_units_summary = df.set_index('Date')['Total_Amount'].resample('Q').sum().reset_index()


# --- Plotting Monthly Units Sold ---
plt.figure(figsize=(12, 6))

sns.lineplot(
    x='Date',
    y='Total_Amount',
    data=monthly_units_summary, # Use the monthly aggregated data
    color='magenta',
    linewidth=1.5
)

plt.title('Quarterly Amound', fontsize=20, fontweight='bold')
plt.xlabel('Date (End of Quarter)', fontsize=14) # Changed label to reflect monthly aggregation
plt.ylabel('Total_Amount', fontsize=14) # Changed label to reflect total units
plt.xticks(rotation=90, ha='right')
plt.grid(False) # Added grid for time series readability
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(16,8))
weekly = df.set_index('Date').resample('Q')[['Total_Purchases', 'Total_Amount']].sum()
# First axis (Units Sold)
ax1.plot(weekly.index, weekly['Total_Purchases'], marker='o', color='Black', label='Units Sold')
ax1.set_xlabel("Month End Date")
ax1.set_ylabel("Units Sold", color='magenta')
ax1.tick_params(axis='y', labelcolor='magenta')

# Second axis (Revenue)
ax2 = ax1.twinx()
ax2.plot(weekly.index, weekly['Total_Amount'], marker='^', color='orange', label='Revenue')
ax2.set_ylabel("Revenue", color='orange')
ax2.tick_params(axis='y', labelcolor='orange')

plt.title("Quarterly Sales Performance")
fig.tight_layout()
plt.show()

# %% [markdown]
# top N **analysis**

# %%
def plot_categorical_donut(dataframe, column_name, n_categories=7, figsize=(10, 10)):
    """
    Generates and displays a donut chart for the top N categories of a specified column.

    Parameters:
    dataframe (pd.DataFrame): The input DataFrame.
    column_name (str): The name of the categorical column to plot.
    n_categories (int): The number of top categories to display explicitly.
                        Remaining categories will be grouped into 'Other'.
    figsize (tuple): A tuple (width, height) for the figure size.
    """
    if column_name not in dataframe.columns:
        print(f"Error: Column '{column_name}' not found in the DataFrame.")
        return

    # Calculate value counts
    counts = dataframe[column_name].value_counts()

    # Prepare data for plotting: select top N and sum the rest into 'Other'
    if len(counts) > n_categories:
        top_n = counts.head(n_categories)
        other_sum = counts.iloc[n_categories:].sum()
        if other_sum > 0:
            plot_data = pd.concat([top_n, pd.Series({'Other': other_sum})])
        else:
            plot_data = top_n
    else:
        plot_data = counts

    # Define colors
    colors = sns.color_palette('pastel', n_colors=len(plot_data))
    if 'Other' in plot_data.index:
        colors = sns.color_palette('pastel', n_colors=len(plot_data) - 1) + ['gray'] # Distinct color for 'Other'

    # Create figure and axis for the plot
    fig, ax = plt.subplots(figsize=figsize)

    # Plotting the donut chart
    wedges, texts, autotexts = ax.pie(
        plot_data,
        labels=plot_data.index,
        autopct='%1.1f%%',       # Format percentages
        startangle=90,           # Start at the top
        colors=colors,
        pctdistance=0.8,         # Position of percentage labels (closer to center of donut hole)
        labeldistance=1.05,      # Position of category labels (outside the donut)
        wedgeprops=dict(width=0.4, edgecolor='black', linewidth=1) # Donut hole via width
    )

    # Customize percentage labels
    for autotext in autotexts:
        autotext.set_color('black')
        autotext.set_fontsize(12)
        autotext.set_fontweight('bold')

    # Customize category labels
    for text in texts:
        text.set_fontsize(12)

    # Set title
    ax.set_title(f'', fontsize=16, fontweight='bold')
    ax.axis('equal') # Ensure circle

    plt.tight_layout()
    plt.show()

# %%
plot_categorical_donut(df, 'Shipping_Method', n_categories=7 , figsize=(6,4))

# %%
plot_categorical_donut(df, 'Payment_Method', n_categories=7 , figsize=(6,4))

# %%
plot_categorical_donut(df, 'Order_Status', n_categories=7 , figsize=(6,4))

# %%
plot_categorical_donut(df, 'Customer_Segment', n_categories=7 , figsize=(6,4))

# %%
plot_categorical_donut(df, 'City', n_categories=5 , figsize=(6,4))

# %%
# --- Step 1: Aggregate total sales by city ---
city_sales = (
    df.groupby('City')['Total_Purchases']
      .sum()
      .reset_index()
      .sort_values('Total_Purchases', ascending=False).head(5)
)

# --- Step 2: Plot ---
plt.figure(figsize=(12,6))
sns.barplot(
    data=city_sales,
    x='City',
    y='Total_Purchases',
    palette='pastel',
    edgecolor='black'
)

plt.title('Which City sell most Product')
plt.xlabel('City')
plt.ylabel('Total Purchases')
plt.show()

# %%
df['Customer_Segment'].value_counts()
# Out:
# Customer_Segment
# Regular    146221
# New         91187
# Premium     64387
# Name: count, dtype: int64

# %% [markdown]
# Multiverse ***Analysys***

# %%
# Count how many times each rating appears for each age
age_rating = pd.crosstab(df['Age'], df['Customer_Segment'])

plt.figure(figsize=(12,6))
age_rating.plot(kind='bar', figsize=(24,6), edgecolor='black')

plt.title('Customer_Segment Distribution by Age')
plt.xlabel('Age')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Customer_Segment')
plt.show()

# %%
# Count how many times each rating appears for each age
age_rating = pd.crosstab(df['Age'], df['Payment_Method'])

plt.figure(figsize=(12,6))
age_rating.plot(kind='bar', figsize=(24,6), edgecolor='black')

plt.title('Payment_Method Distribution by Age')
plt.xlabel('Age')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Payment_Method')
plt.show()

# %% [markdown]
# last n analysis
# **bold text**

# %%
# --- Step 1: Aggregate total sales by city ---
city_sales = (
    df.groupby('City')['Total_Purchases']
      .sum()
      .reset_index()
      .sort_values('Total_Purchases', ascending=False).tail(5)
)

# --- Step 2: Plot ---
plt.figure(figsize=(12,6))
sns.barplot(
    data=city_sales,
    x='City',
    y='Total_Purchases',
    palette='pastel',
    edgecolor='black'
)

plt.title('Which City sell lowest Product')
plt.xlabel('City')
plt.ylabel('Total Purchases')
plt.show()

# %%
# --- Step 1: Aggregate total sales by city ---
city_sales = (
    df.groupby('products')['Total_Purchases']
      .sum()
      .reset_index()
      .sort_values('Total_Purchases', ascending=False).tail(5)
)

# --- Step 2: Plot ---
plt.figure(figsize=(12,6))
sns.barplot(
    data=city_sales,
    x='products',
    y='Total_Purchases',
    palette='pastel',
    edgecolor='black'
)

plt.title('Top 5 lowest selling product')
plt.xlabel('products')
plt.ylabel('Total Purchases')
plt.show()
